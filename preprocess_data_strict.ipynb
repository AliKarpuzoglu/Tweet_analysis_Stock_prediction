# %%
import pandas as pd

# %%
tweets = pd.read_json("../data/tweets_2018_01.json")
print("Tweets DF shape: ", tweets.shape)
tweets.head()
# Out:
# Tweets DF shape:  (46833, 21)
#    has_media                        hashtags  \
# 0  False      []
# 1  True       [teslamodelx, tesla, elonmusk]
# 2  True       [Tech, GeekyNurturepic]
# 3  False      []
# 4  False      []
#
#                                             img_urls  is_replied  is_reply_to  \
# 0  []                                                 False       False
# 1  [https://pbs.twimg.com/media/DSfi5SIWkAEEYNh.jpg]  False       False
# 2  [https://pbs.twimg.com/media/DSfnRLKUEAAyeR0.jpg]  False       False
# 3  []                                                 False       False
# 4  []                                                 True        True
#
#    likes                    links     parent_tweet_id  replies  \
# 0  0      [https://goo.gl/SGxWkJ]                      0
# 1  0      []                                           0
# 2  0      [http://dlvr.it/Q8TgQr]                      0
# 3  1      []                                           0
# 4  0      []                       947944656528134149  1
#
#                                                   reply_to_users  ...  \
# 0  []                                                             ...
# 1  []                                                             ...
# 2  []                                                             ...
# 3  []                                                             ...
# 4  [{'screen_name': 'simack_', 'user_id': '885513300506791936'}]  ...
#
#     screen_name  \
# 0  unlockMEDIA
# 1  unlockMEDIA
# 2  geekynurture
# 3  JELtech_LLC
# 4  manfredheck1
#
#                                                                                                                                                                                                                                                                                        text  \
# 0  RT @entftw: CHECK THIS OUT! Elon Musk: Tesla, SpaceX, and the Quest for a Fantastic Future https://goo.gl/SGxWkJ
# 1  RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
# 2  #Tech Verne Troyer got a 'Tesla' for Christmas and it's amazing - Roadshow http://dlvr.it/Q8TgQr  #GeekyNurturepic.twitter.com/0Ri3E6wd2k
# 3  RT BenedictEvans "wileycwj Pretty much every AV team other than Tesla is using lidar. This is because of the view they take of how soon vision will work"
# 4  Es gibt mittlerw. schon einige Tesla, die weit über 200.000 km gefahren sind (mit der gl. Batterie). Also erzähl.Sie bitte nicht solchen Müll.Mein Tesla ist über 2 Jahre alt + läuft wie am ersten Tag, mein Leaf ebenso (5 Jahre alt). Die ZOE + der i3 im Fuhrpark sind noch zu jung.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text_html  \
# 0  <p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="en">RT <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="889242251259506689" dir="ltr" href="/entftw"><s>@</s><b>entftw</b></a>: CHECK THIS OUT! Elon Musk: <strong>Tesla</strong>, SpaceX, and the Quest for a Fantastic Future <a class="twitter-timeline-link u-hidden" data-expanded-url="https://goo.gl/SGxWkJ" dir="ltr" href="https://t.co/PCcTGOpKec" rel="nofollow noopener" target="_blank" title="https://goo.gl/SGxWkJ"><span class="tco-ellipsis"></span><span class="invisible">https://</span><span class="js-display-url">goo.gl/SGxWkJ</span><span class="invisible"></span><span class="tco-ellipsis"><span class="invisible"> </span></span></a></p>
# 1  <p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="en">RT <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="393554379" dir="ltr" href="/antonio_andrew"><s>@</s><b>antonio_andrew</b></a>: Just finished reading the bio of Elon Musk, founder of PayPal, <strong>Tesla</strong>, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/teslamodelx?src=hash"><s>#</s><b>teslamodelx</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/tesla?src=hash"><s>#</s><b><strong>tesla</strong></b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/elonmusk?src=hash"><s>#</s><b>elonmusk</b></a> …<a class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr" href="https://t.co/pFGrGEbTOp">pic.twitter.com/pFGrGEbTOp</a></p>
# 2  <p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="en"><a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Tech?src=hash"><s>#</s><b>Tech</b></a> Verne Troyer got a '<strong>Tesla</strong>' for Christmas and it's amazing - Roadshow <a class="twitter-timeline-link" data-expanded-url="http://dlvr.it/Q8TgQr" dir="ltr" href="https://t.co/3DDYSkQ0Gv" rel="nofollow noopener" target="_blank" title="http://dlvr.it/Q8TgQr"><span class="tco-ellipsis"></span><span class="invisible">http://</span><span class="js-display-url">dlvr.it/Q8TgQr</span><span class="invisible"></span><span class="tco-ellipsis"><span class="invisible"> </span></span></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/GeekyNurture?src=hash"><s>#</s><b>GeekyNurture</b></a><a class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr" href="https://t.co/0Ri3E6wd2k">pic.twitter.com/0Ri3E6wd2k</a></p>
# 3  <p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="en">RT BenedictEvans "wileycwj Pretty much every AV team other than <strong>Tesla</strong> is using lidar. This is because of the view they take of how soon vision will work"</p>
# 4  <p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="de">Es gibt mittlerw. schon einige <strong>Tesla</strong>, die weit über 200.000 km gefahren sind (mit der gl. Batterie). Also erzähl.Sie bitte nicht solchen Müll.Mein <strong>Tesla</strong> ist über 2 Jahre alt + läuft wie am ersten Tag, mein Leaf ebenso (5 Jahre alt). Die ZOE + der i3 im Fuhrpark sind noch zu jung.</p>
#
#             timestamp    timestamp_epochs            tweet_id  \
# 0 2018-01-01 23:59:15 2018-01-01 23:59:15  947980572823089152
# 1 2018-01-01 23:59:15 2018-01-01 23:59:15  947980570868502528
# 2 2018-01-01 23:59:05 2018-01-01 23:59:05  947980531190284288
# 3 2018-01-01 23:59:03 2018-01-01 23:59:03  947980519253438464
# 4 2018-01-01 23:58:53 2018-01-01 23:58:53  947980478245679104
#
#                                  tweet_url             user_id      username  \
# 0  /unlockMEDIA/status/947980572823089157   28756003            UnlockMedia
# 1  /unlockMEDIA/status/947980570868502533   28756003            UnlockMedia
# 2  /geekynurture/status/947980531190284289  712620672007086080  Geeky
# 3  /JELtech_LLC/status/947980519253438464   859082383739539456  JELtech
# 4  /manfredheck1/status/947980478245679104  756589906634371072  Manfred Heck
#
#   video_url
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 21 columns]

# %%
# drop columns we will not use
tweets.drop(columns='has_media parent_tweet_id video_url user_id tweet_url tweet_id is_reply_to reply_to_users '
            'timestamp_epochs text_html screen_name is_replied'.split(), inplace=True)

# rearrange columns
cols = 'timestamp hashtags text username likes replies retweets links img_urls'.split() 
tweets = tweets[cols]

print("Tweets DF shape: ", tweets.shape)
tweets.head()
# Out:
# Tweets DF shape:  (46833, 9)
#             timestamp                        hashtags  \
# 0 2018-01-01 23:59:15  []
# 1 2018-01-01 23:59:15  [teslamodelx, tesla, elonmusk]
# 2 2018-01-01 23:59:05  [Tech, GeekyNurturepic]
# 3 2018-01-01 23:59:03  []
# 4 2018-01-01 23:58:53  []
#
#                                                                                                                                                                                                                                                                                        text  \
# 0  RT @entftw: CHECK THIS OUT! Elon Musk: Tesla, SpaceX, and the Quest for a Fantastic Future https://goo.gl/SGxWkJ
# 1  RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
# 2  #Tech Verne Troyer got a 'Tesla' for Christmas and it's amazing - Roadshow http://dlvr.it/Q8TgQr  #GeekyNurturepic.twitter.com/0Ri3E6wd2k
# 3  RT BenedictEvans "wileycwj Pretty much every AV team other than Tesla is using lidar. This is because of the view they take of how soon vision will work"
# 4  Es gibt mittlerw. schon einige Tesla, die weit über 200.000 km gefahren sind (mit der gl. Batterie). Also erzähl.Sie bitte nicht solchen Müll.Mein Tesla ist über 2 Jahre alt + läuft wie am ersten Tag, mein Leaf ebenso (5 Jahre alt). Die ZOE + der i3 im Fuhrpark sind noch zu jung.
#
#        username  likes  replies  retweets                    links  \
# 0  UnlockMedia   0      0        0         [https://goo.gl/SGxWkJ]
# 1  UnlockMedia   0      0        0         []
# 2  Geeky         0      0        0         [http://dlvr.it/Q8TgQr]
# 3  JELtech       1      0        0         []
# 4  Manfred Heck  0      1        0         []
#
#                                             img_urls
# 0  []
# 1  [https://pbs.twimg.com/media/DSfi5SIWkAEEYNh.jpg]
# 2  [https://pbs.twimg.com/media/DSfnRLKUEAAyeR0.jpg]
# 3  []
# 4  []

# %%
## remove all tweets that do not have a tesla or elonmusk hashtag
# check hashtags column types first
print(tweets['hashtags'].dtypes)
# Out:
# object

# %%
#INSIGHT: Even the dtype of the hashtags column is 'object', when we access it, we get a list
print(type(tweets.iloc[0]['hashtags']))
print(' '.join(tweets.iloc[1]['hashtags']))
print('tesla' in ' '.join(tweets.iloc[1]['hashtags']))
type(tweets.iloc[1]['hashtags'][0])
# Out:
# <class 'list'>
# teslamodelx tesla elonmusk
# True
# str

# %%
# TODO: maybe we should not delete other tweets as this drastically reduces our data size... 
# on the other hand quite a lot of other tweets are rubbish.
# Consider: there are several hashtags containing the string 'tesla' in them, which are all relevant to us!
# tweets = tweets['tesla' in ' '.join(tweets['hashtags'])]
# tweets = tweets['tesla' in tweets['hashtags'].apply(' '.join)
# tweets = tweets[tweets['hashtags'].str.contains('tesla')==True]
tweets = tweets[tweets['hashtags'].apply(lambda tags: any(tag in ' '.join(tags).lower() for tag in ['tesla', 'elon', 'tsla', 'musk']))==True]
print(tweets.shape)
tweets.head()
# Out:
# (4672, 9)
#              timestamp  \
# 1  2018-01-01 23:59:15
# 7  2018-01-01 23:56:12
# 15 2018-01-01 23:51:48
# 16 2018-01-01 23:51:39
# 19 2018-01-01 23:59:15
#
#                                                                           hashtags  \
# 1   [teslamodelx, tesla, elonmusk]
# 7   [tesla, spacex, FalconHeavy, ElonMusk, bitcoin, cryptocurrency, ethereumhttps]
# 15  [Coils, Wires, Tesla, Collectors]
# 16  [Hyperloop, Tesla, virgin]
# 19  [teslamodelx, tesla, elonmusk]
#
#                                                                                                                                                                                                                                                                           text  \
# 1   RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
# 7   @elonmusk @SpaceX @Tesla #tesla #spacex #FalconHeavy #ElonMusk #bitcoin #cryptocurrency #ethereumhttps://twitter.com/coinsultants/status/946913553512108033 …
# 15  What is the name of the device that allows for infinite energy in the anime "Dimension W"? \n #Coils,    #Wires, \n #Tesla or  #Collectors?
# 16  I thought this hyper loop thing was serious? Or am I missing something here? @elonmusk #Hyperloop #Tesla #virgin @richardbransonpic.twitter.com/slRxljoeyX
# 19  RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
#
#         username  likes  replies  retweets  \
# 1   UnlockMedia   0      0        0
# 7   Coinsultants  0      0        0
# 15  OpenTDB       0      0        0
# 16  𝙄𝙖𝙣 𝘾𝙡𝙖𝙥𝙝𝙖𝙢   0      0        0
# 19  UnlockMedia   0      0        0
#
#                                                            links  \
# 1   []
# 7   [https://twitter.com/coinsultants/status/946913553512108033]
# 15  []
# 16  []
# 19  []
#
#                                                                                               img_urls
# 1   [https://pbs.twimg.com/media/DSfi5SIWkAEEYNh.jpg]
# 7   []
# 15  []
# 16  [https://pbs.twimg.com/media/DSflj3dXkAARtsy.jpg, https://pbs.twimg.com/media/DSflj3ZW4AA17q5.jpg]
# 19  [https://pbs.twimg.com/media/DSfi5SIWkAEEYNh.jpg]

# %% [markdown]
# #### Observation:
# We have tweets in different languages: Already saw one in German. Would suggest to first ignore this fact.

# %%
# print some tweets to see how we could further clean them up
print('\n\n'.join(list(tweets.iloc[0:20:5,2])))
# Out:
# RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
#
# @elonmusk @SpaceX @Tesla #tesla #spacex #FalconHeavy #ElonMusk #bitcoin #cryptocurrency #ethereumhttps://twitter.com/coinsultants/status/946913553512108033 …
#
# With the application of Nikola Tesla's technology, "Qi" can be generated artificially ...
# #qi #scalar #weapon #tesla #mantra
#
# First Used Tesla Model 3 Sold, Where's Elon, & Tesla Model 3 Delivery Pics… https://goo.gl/fb/cDu1ad  #ElonMusk mediat

# %% [markdown]
# #### Observations:
# - remove Links (can also later be removed by spacy!)
# - some tweets do not contain Tesla related information at all

# %%
# remove links from all the tweet texts
tweets['text'] = [text.replace(links[0], '') if len(links)>0 else text 
                  for (text,links) in zip(tweets['text'],tweets['links']) ]
tweets['text'] = [text.replace(links[0], '') if len(links)>0 else text 
                  for (text,links) in zip(tweets['text'],tweets['img_urls']) ]

print('\n\n'.join(list(tweets.iloc[0:20:5,2])))
# Out:
# RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
#
# @elonmusk @SpaceX @Tesla #tesla #spacex #FalconHeavy #ElonMusk #bitcoin #cryptocurrency #ethereum …
#
# With the application of Nikola Tesla's technology, "Qi" can be generated artificially ...
# #qi #scalar #weapon #tesla #mantra
#
# First Used Tesla Model 3 Sold, Where's Elon, & Tesla Model 3 Delivery Pics…   #ElonMusk mediat

# %%
# Some Links could still not be removed as they are not saved as an image url or link. We'll remove them later with spacy.
# remove columns "links" and "img_urls"
tweets.drop(columns=['links', 'img_urls'], inplace=True)
tweets.head()
# Out:
#              timestamp  \
# 1  2018-01-01 23:59:15
# 7  2018-01-01 23:56:12
# 15 2018-01-01 23:51:48
# 16 2018-01-01 23:51:39
# 19 2018-01-01 23:59:15
#
#                                                                           hashtags  \
# 1   [teslamodelx, tesla, elonmusk]
# 7   [tesla, spacex, FalconHeavy, ElonMusk, bitcoin, cryptocurrency, ethereumhttps]
# 15  [Coils, Wires, Tesla, Collectors]
# 16  [Hyperloop, Tesla, virgin]
# 19  [teslamodelx, tesla, elonmusk]
#
#                                                                                                                                                                                                                                                                           text  \
# 1   RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
# 7   @elonmusk @SpaceX @Tesla #tesla #spacex #FalconHeavy #ElonMusk #bitcoin #cryptocurrency #ethereum …
# 15  What is the name of the device that allows for infinite energy in the anime "Dimension W"? \n #Coils,    #Wires, \n #Tesla or  #Collectors?
# 16  I thought this hyper loop thing was serious? Or am I missing something here? @elonmusk #Hyperloop #Tesla #virgin @richardbransonpic.twitter.com/slRxljoeyX
# 19  RT @antonio_andrew: Just finished reading the bio of Elon Musk, founder of PayPal, Tesla, SpaceX, Solar City, and a host of other amazing projects. Great read of a futurama visionary for simply a better life. #teslamodelx #tesla #elonmusk …pic.twitter.com/pFGrGEbTOp
#
#         username  likes  replies  retweets
# 1   UnlockMedia   0      0        0
# 7   Coinsultants  0      0        0
# 15  OpenTDB       0      0        0
# 16  𝙄𝙖𝙣 𝘾𝙡𝙖𝙥𝙝𝙖𝙢   0      0        0
# 19  UnlockMedia   0      0        0

# %% [markdown]
# ### Discussion:
# Actually I don't think that tweets that were not liked and retweeted could possibly influence the stock market. So we might try to remove them. On the other hand, a tweet could be a reaction to a change in the stock price, don't get any attention (no likes and retweets) but still relevant!

# %%
best_tweets = tweets[tweets['likes']>0]
print(best_tweets.shape)
best_tweets = best_tweets[best_tweets['replies']>0]
print(best_tweets.shape)
best_tweets = best_tweets[best_tweets['retweets']>0]
print(best_tweets.shape)
pd.set_option('display.max_colwidth', -1)
best_tweets.head()
# Out:
# (1782, 7)
# (387, 7)
# (268, 7)
#               timestamp  \
# 165 2018-01-01 23:15:29
# 376 2018-01-01 22:09:19
# 378 2018-01-01 22:09:12
# 381 2018-01-01 22:08:56
# 384 2018-01-01 22:08:54
#
#                                                                                                                                             hashtags  \
# 165  [Tesla]
# 376  [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 378  [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 381  [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 384  [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
#
#                                                                                                                                                                       text  \
# 165  “Precisely one of the most gratifying results of intellectual evolution is the continuous opening up of new and greater prospects.”\n–#Tesla
# 376  #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/Y8j32wPgVJ
# 378  #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/sQLFnFpq6z
# 381  #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/xEO8ZNGtYT
# 384  #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/bKL2dSDd1t
#
#                  username  likes  replies  retweets
# 165  Á̵̢̙͉̫ 𝐫 𝐝 𝐢 𝐧 ≤≥ 🌐  16     1        1
# 376  Our Creator           3      2        2
# 378  Our Creator           2      1        1
# 381  Our Creator           6      1        4
# 384  Our Creator           5      1        2

# %%
# remove tweets with too many hashtags, where 'tesla' is just a single one of and not that relevant
# check such kind of tweets first
too_many_tags = best_tweets[best_tweets['hashtags'].apply(lambda tags: len(tags)>10)==True]
print(too_many_tags.shape)
pd.set_option('display.max_colwidth', -1)
too_many_tags.head()
# Out:
# (17, 7)
#                timestamp  \
# 376  2018-01-01 22:09:19
# 378  2018-01-01 22:09:12
# 381  2018-01-01 22:08:56
# 384  2018-01-01 22:08:54
# 1522 2018-01-01 18:12:09
#
#                                                                                                                                              hashtags  \
# 376   [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 378   [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 381   [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 384   [NASA, sun, moon, FlatEarth, science, God, space, future, past, earth, stars, sex, love, music, nature, Creation, world, life, Tesla, globepic]
# 1522  [electric, car, copper, wiring, EVs, infrastructure, Energy, Storage, lithium, cars, Tesla, BYD]
#
#                                                                                                                                                                                                                                                                      text  \
# 376   #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/Y8j32wPgVJ
# 378   #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/sQLFnFpq6z
# 381   #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/xEO8ZNGtYT
# 384   #NASA #sun #moon #FlatEarth #science #God #space #future #past #earth #stars #sex #love #music #nature #Creation #world #life #Tesla #globepic.twitter.com/bKL2dSDd1t
# 1522  A single #electric #car can have up to 6 km of #copper #wiring. Copper is not only needed for #EVs, but it is vital for all #infrastructure and #Energy #Storage will demand more #lithium and copper than even electric #cars  … #Tesla #BYD $JJC $GDX $GDXJ @CNBC
#
#                          username  likes  replies  retweets
# 376   Our Creator                  3      2        2
# 378   Our Creator                  2      1        1
# 381   Our Creator                  6      1        4
# 384   Our Creator                  5      1        2
# 1522  Kirill Klip 🌎🔥#rEVolution🔌🎸  22     1        25

# %%
# some tweets with many tags seem to be quite relevant, so just remove those coming from specific users
remove_users = ['ADRIAN AGUILAR', 'Our Creator']

print(best_tweets.shape)
best_tweets = best_tweets[best_tweets['username'].apply(lambda user: user in remove_users)==False]
print(best_tweets.shape)
best_tweets.head()
# Out:
# (268, 7)
# (262, 7)
#                timestamp  \
# 165  2018-01-01 23:15:29
# 489  2018-01-01 21:52:27
# 527  2018-01-01 21:42:16
# 802  2018-01-01 20:54:24
# 1087 2018-01-01 20:00:00
#
#                                                              hashtags  \
# 165   [Tesla]
# 489   [NewYearsDay, NewYearsEve2017, HappyNewYear, Tesla]
# 527   [Tesla, TeslaMotors, ElectricVehicle, ElonMusk, TeslaPowerwall]
# 802   [Ganador, Gemelos, Tesla, enhorabuena]
# 1087  [Tesla]
#
#                                                                                                                                                                               text  \
# 165   “Precisely one of the most gratifying results of intellectual evolution is the continuous opening up of new and greater prospects.”\n–#Tesla
# 489   It’s 2018.  We have self driving cars but still no cure for a hangover. We need to prioritize in the new year.  #NewYearsDay #NewYearsEve2017 #HappyNewYear #Tesla @elonmusk
# 527   #Tesla Powerwall initiative in Vermont is growing, learn more:   $TSLA #TeslaMotors #ElectricVehicle #ElonMusk #TeslaPowerwall
# 802   #Ganador #Gemelos #Tesla @Isilopez_101 #enhorabuena.pic.twitter.com/yxxHKj2TDo
# 1087  #Tesla hat bislang nur Verluste angehäuft. Ist die Tesla-Aktie trotzdem eine gute Idee?  …
#
#                     username  likes  replies  retweets
# 165   Á̵̢̙͉̫ 𝐫 𝐝 𝐢 𝐧 ≤≥ 🌐    16     1        1
# 489   Nicholas E. Calhoun     2      1        1
# 527   EVANNEX for Tesla       33     1        8
# 802   MQE Más Que Eléctricos  5      1        2
# 1087  Frankfurter Allgemeine  6      3        2

# %% [markdown]
# ### Observation:
# Even after doing quite a lot of preprocessing, we still see some tweets that don't for sure contain relevant information. In the scope of this project, we stop the data cleaning at this moment, but would definitely do much more in a real world scenario, including collecting much more tweets.
