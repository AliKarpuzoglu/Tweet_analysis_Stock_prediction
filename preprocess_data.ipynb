# %%
import pandas as pd

# %%
tweets = pd.read_json("../data/tweets_2018_01.json")
print("Tweets DF shape: ", tweets.shape)
tweets.head()
# Out:
# Tweets DF shape:  (46833, 21)
#    has_media                        hashtags  \
# 0      False                              []
# 1       True  [teslamodelx, tesla, elonmusk]
# 2       True         [Tech, GeekyNurturepic]
# 3      False                              []
# 4      False                              []
#
#                                             img_urls  is_replied  is_reply_to  \
# 0                                                 []       False        False
# 1  [https://pbs.twimg.com/media/DSfi5SIWkAEEYNh.jpg]       False        False
# 2  [https://pbs.twimg.com/media/DSfnRLKUEAAyeR0.jpg]       False        False
# 3                                                 []       False        False
# 4                                                 []        True         True
#
#    likes                    links     parent_tweet_id  replies  \
# 0      0  [https://goo.gl/SGxWkJ]                            0
# 1      0                       []                            0
# 2      0  [http://dlvr.it/Q8TgQr]                            0
# 3      1                       []                            0
# 4      0                       []  947944656528134149        1
#
#                                       reply_to_users  ...   screen_name  \
# 0                                                 []  ...   unlockMEDIA
# 1                                                 []  ...   unlockMEDIA
# 2                                                 []  ...  geekynurture
# 3                                                 []  ...   JELtech_LLC
# 4  [{'screen_name': 'simack_', 'user_id': '885513...  ...  manfredheck1
#
#                                                 text  \
# 0  RT @entftw: CHECK THIS OUT! Elon Musk: Tesla, ...
# 1  RT @antonio_andrew: Just finished reading the ...
# 2  #Tech Verne Troyer got a 'Tesla' for Christmas...
# 3  RT BenedictEvans "wileycwj Pretty much every A...
# 4  Es gibt mittlerw. schon einige Tesla, die weit...
#
#                                            text_html           timestamp  \
# 0  <p class="TweetTextSize js-tweet-text tweet-te... 2018-01-01 23:59:15
# 1  <p class="TweetTextSize js-tweet-text tweet-te... 2018-01-01 23:59:15
# 2  <p class="TweetTextSize js-tweet-text tweet-te... 2018-01-01 23:59:05
# 3  <p class="TweetTextSize js-tweet-text tweet-te... 2018-01-01 23:59:03
# 4  <p class="TweetTextSize js-tweet-text tweet-te... 2018-01-01 23:58:53
#
#      timestamp_epochs            tweet_id  \
# 0 2018-01-01 23:59:15  947980572823089152
# 1 2018-01-01 23:59:15  947980570868502528
# 2 2018-01-01 23:59:05  947980531190284288
# 3 2018-01-01 23:59:03  947980519253438464
# 4 2018-01-01 23:58:53  947980478245679104
#
#                                  tweet_url             user_id      username  \
# 0   /unlockMEDIA/status/947980572823089157            28756003   UnlockMedia
# 1   /unlockMEDIA/status/947980570868502533            28756003   UnlockMedia
# 2  /geekynurture/status/947980531190284289  712620672007086080         Geeky
# 3   /JELtech_LLC/status/947980519253438464  859082383739539456       JELtech
# 4  /manfredheck1/status/947980478245679104  756589906634371072  Manfred Heck
#
#   video_url
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 21 columns]

# %%
# drop columns we will not use
tweets.drop(columns='has_media parent_tweet_id video_url user_id tweet_url tweet_id '
            'timestamp_epochs text_html screen_name img_urls'.split(), inplace=True)
print("Tweets DF shape: ", tweets.shape)
tweets.head()
# Out:
# Tweets DF shape:  (46833, 11)
#                          hashtags  is_replied  is_reply_to  likes  \
# 0                              []       False        False      0
# 1  [teslamodelx, tesla, elonmusk]       False        False      0
# 2         [Tech, GeekyNurturepic]       False        False      0
# 3                              []       False        False      1
# 4                              []        True         True      0
#
#                      links  replies  \
# 0  [https://goo.gl/SGxWkJ]        0
# 1                       []        0
# 2  [http://dlvr.it/Q8TgQr]        0
# 3                       []        0
# 4                       []        1
#
#                                       reply_to_users  retweets  \
# 0                                                 []         0
# 1                                                 []         0
# 2                                                 []         0
# 3                                                 []         0
# 4  [{'screen_name': 'simack_', 'user_id': '885513...         0
#
#                                                 text           timestamp  \
# 0  RT @entftw: CHECK THIS OUT! Elon Musk: Tesla, ... 2018-01-01 23:59:15
# 1  RT @antonio_andrew: Just finished reading the ... 2018-01-01 23:59:15
# 2  #Tech Verne Troyer got a 'Tesla' for Christmas... 2018-01-01 23:59:05
# 3  RT BenedictEvans "wileycwj Pretty much every A... 2018-01-01 23:59:03
# 4  Es gibt mittlerw. schon einige Tesla, die weit... 2018-01-01 23:58:53
#
#        username
# 0   UnlockMedia
# 1   UnlockMedia
# 2         Geeky
# 3       JELtech
# 4  Manfred Heck

# %%
## remove all tweets that do not have a tesla or elonmusk hashtag
# check hashtags column types first
print(tweets['hashtags'].dtypes)
# Out:
# object

# %%
#INSIGHT: Even the dtype of the hashtags column is 'object', when we access it, we get a list
type(tweets.iloc[1]['hashtags'])
# Out:
# list

# %%
tweets = tweets['elon' in ' '.join(tweets['hashtags'])]
