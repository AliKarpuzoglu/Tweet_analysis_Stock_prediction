# %% [markdown]
# #TSLA Stock market prediction

# %%
# first install the yahoo finance library if you don't have it already
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/c2/31/8b374a12b90def92a4e27d0fc595fc43635f395984e36a075244d98bd265/yfinance-0.1.54.tar.gz
# Requirement already satisfied: pandas>=0.24 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from yfinance) (0.25.3)
# Requirement already satisfied: numpy>=1.15 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from yfinance) (1.17.3)
# Requirement already satisfied: requests>=2.20 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from yfinance) (2.22.0)
# Collecting multitasking>=0.0.7
#   Downloading https://files.pythonhosted.org/packages/69/e7/e9f1661c28f7b87abfa08cb0e8f51dad2240a9f4f741f02ea839835e6d18/multitasking-0.0.9.tar.gz
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from requests>=2.20->yfinance) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: six>=1.5 in /Users/ali/anaconda3/envs/ai/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.13.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22411 sha256=e70abd5f3e242575420f70b568e1c4fa5e44544329b8f614f4c9d0bbfa68a290
#   Stored in directory: /Users/ali/Library/Caches/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-cp37-none-any.whl size=8368 sha256=52df191eb9abfca097c1ec4a702577fef18c4d444ff7c5a95a6396b04f4c7a29
#   Stored in directory: /Users/ali/Library/Caches/pip/wheels/37/fa/73/d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.54

# %%
#import
import numpy as np
import spacy
import yfinance as yf

# %%
tsla = yf.Ticker("TSLA")
print(tsla)
tsla.history(period="max")
# Out:
# yfinance.Ticker object <TSLA>
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29   19.00   25.00   17.54   23.89  18766300          0             0
# 2010-06-30   25.79   30.42   23.30   23.83  17187100          0             0
# 2010-07-01   25.00   25.92   20.27   21.96   8218800          0             0
# 2010-07-02   23.00   23.10   18.71   19.20   5139800          0             0
# 2010-07-06   20.00   20.00   15.83   16.11   6866900          0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-01-15  529.76  537.84  516.79  518.50  17368800          0             0
# 2020-01-16  493.75  514.46  492.17  513.49  21736700          0             0
# 2020-01-17  507.61  515.67  503.16  510.50  13629100          0             0
# 2020-01-21  530.25  548.58  528.41  547.20  17749700          0             0
# 2020-01-22  571.89  575.33  561.25  575.28   6102553          0             0
#
# [2408 rows x 7 columns]
